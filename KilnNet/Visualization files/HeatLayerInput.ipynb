# %%
f=open("kiln_check_0.001.txt","w")
file = open("kiln.txt").readlines()
for line in file:
    #print(line)
    a , b, c=line.split(' ')
    if float(c)> 0.001:
        print(a)
        #lon=((float(e)-310688)*0.000686645507798) + 33.332862854
        #lat=((float(fz)-310688)*0.000686645507798) + 33.332862854
        #print(lat)
        f.write("{weight: ")
        f.write(str(100))
        f.write(", location: new google.maps.LatLng(")
        f.write(str(a))
        f.write(",")
        f.write(str(b))
        f.write(")},")
        f.write("\n")
f.close()
# Out:
# 30.11180877685547
# 30.11318206787109
# 30.11798858642578
# 30.12348175048828
# 30.12416839599609
# 30.12554168701172
# 30.12622833251953
# 30.12691497802734
# 30.13309478759766
# 30.13378143310547
# 30.13446807861328
# 30.13515472412109
# 30.11661529541016
# 30.11730194091797
# 30.11867523193359
# 30.12485504150391
# 30.12691497802734
# 30.12760162353516
# 30.12828826904297
# 30.12966156005859
# 30.13240814208984
# 30.13378143310547
# 30.13446807861328
# 30.13515472412109
# 30.11867523193359
# 30.12760162353516
# 30.07953643798828
# 30.11112213134766
# 30.11798858642578
# 30.12279510498047
# 30.12348175048828
# 30.12416839599609
# 30.12622833251953
# 30.12691497802734
# 30.12828826904297
# 30.12897491455078
# 30.12966156005859
# 30.13103485107422
# 30.13309478759766
# 30.13378143310547
# 30.13446807861328
# 30.13515472412109
# 30.10082244873047
# 30.13034820556641
# 30.11936187744141
# 30.12073516845703
# 30.12966156005859
# 30.13309478759766
# 30.10425567626953
# 30.10974884033203
# ...

# %%
f=open("YOLO-Detection-0.001.txt","w")
file = open("kiln.txt").readlines()
for line in file:
    #print(line)
    a , b, c=line.split(' ')
    if float(c)> 0.001:
        print(a)
        #lon=((float(e)-310688)*0.000686645507798) + 33.332862854
        #lat=((float(fz)-310688)*0.000686645507798) + 33.332862854
        #print(lat)
        f.write(str(a))
        f.write(",")
        f.write(str(b))
        f.write("\n")
f.close()
# Out:
# 30.11180877685547
# 30.11318206787109
# 30.11798858642578
# 30.12348175048828
# 30.12416839599609
# 30.12554168701172
# 30.12622833251953
# 30.12691497802734
# 30.13309478759766
# 30.13378143310547
# 30.13446807861328
# 30.13515472412109
# 30.11661529541016
# 30.11730194091797
# 30.11867523193359
# 30.12485504150391
# 30.12691497802734
# 30.12760162353516
# 30.12828826904297
# 30.12966156005859
# 30.13240814208984
# 30.13378143310547
# 30.13446807861328
# 30.13515472412109
# 30.11867523193359
# 30.12760162353516
# 30.07953643798828
# 30.11112213134766
# 30.11798858642578
# 30.12279510498047
# 30.12348175048828
# 30.12416839599609
# 30.12622833251953
# 30.12691497802734
# 30.12828826904297
# 30.12897491455078
# 30.12966156005859
# 30.13103485107422
# 30.13309478759766
# 30.13378143310547
# 30.13446807861328
# 30.13515472412109
# 30.10082244873047
# 30.13034820556641
# 30.11936187744141
# 30.12073516845703
# 30.12966156005859
# 30.13309478759766
# 30.10425567626953
# 30.10974884033203
# ...
