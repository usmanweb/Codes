# %% [markdown]
# # Mounting and Changing the Working Directory

# %%
# %cd ..

DATASET = "datasets/asia14/Training Set/"
# Out:
# /Users/wadoodislam/PycharmProjects/STGNN_remote_sensing

# %%
# !git clone https://github.com/graphdeeplearning/benchmarking-gnns.git
# Out:
# fatal: destination path 'benchmarking-gnns' already exists and is not an empty directory.

# %%
# !gdown --id 1-IdZu70SqCMLa5kBGNnuZJzjIQAKoYqQ -O datasets/asia14.zip  # Asia 14 Dataset
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-IdZu70SqCMLa5kBGNnuZJzjIQAKoYqQ
# To: /Users/wadoodislam/PycharmProjects/STGNN_remote_sensing/datasets/asia14.zip
# 395MB [00:42, 9.34MB/s]

# %%
# !unzip datasets/asia14.zip -d datasets/asia14/
# Out:
# Archive:  datasets/asia14.zip
#    creating: datasets/asia14/Training Set/
#    creating: datasets/asia14/Training Set/barrenland/
#  extracting: datasets/asia14/Training Set/barrenland/0.png
#  extracting: datasets/asia14/Training Set/barrenland/1.png
#  extracting: datasets/asia14/Training Set/barrenland/10.png
#   inflating: datasets/asia14/Training Set/barrenland/100.png
#  extracting: datasets/asia14/Training Set/barrenland/101.png
#   inflating: datasets/asia14/Training Set/barrenland/102.png
#   inflating: datasets/asia14/Training Set/barrenland/103.png
#   inflating: datasets/asia14/Training Set/barrenland/104.png
#   inflating: datasets/asia14/Training Set/barrenland/105.png
#   inflating: datasets/asia14/Training Set/barrenland/106.png
#   inflating: datasets/asia14/Training Set/barrenland/107.png
#   inflating: datasets/asia14/Training Set/barrenland/108.png
#   inflating: datasets/asia14/Training Set/barrenland/109.png
# ...

# %%
# !pwd
# Out:
# /src/notebooks
